# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h2>Python Programming - 2301CS404</b></center>
# <center><b><h2>Lab - 5</b></center>
# <center><b><h3>Roll No.: 418</b></center>
# <center><b><h3>Name: Bhavik A. Parmar</b></center>
# <pre>

# %% [markdown]
# ### 1) Character Category Counter
# **Problem:** Count uppercase, lowercase, digits, and special characters in a string.
#
# **Sample Inputs & Outputs:**
# - Input: `Python3@Lab` → Uppercase: 2, Lowercase: 7, Digits: 1, Special: 1
# - Input: `HELLO123` → Uppercase: 5, Lowercase: 0, Digits: 3, Special: 0
# - Input: `hi@#9` → Uppercase: 0, Lowercase: 2, Digits: 1, Special: 2

# %%
s = input("Enter Something :")
up = 0
lw = 0
digit = 0 
spe = 0
for i in s:
    if(i.isupper()):
        up += 1
    elif(i.islower()):
        lw += 1
    elif(i.isdigit()):
        digit += 1
    elif not (i.isalnum()):
        spe += 1
    else:
        print("Enter Valid Input.")
print("Total Number Of Uppercase :", up)
print("Total Number Of Lowercase :", lw)
print("Total Number Of Digit :", digit)
print("Total Number Of Special :", spe)
# Out:
# Enter Something : Python3@Lab
# Total Number Of Uppercase : 2
# Total Number Of Lowercase : 7
# Total Number Of Digit : 1
# Total Number Of Special : 1

# %% [markdown]
# ### 2) Reverse Each Word
# - Input: `Python is Easy` → `nohtyP si ysaE`
# - Input: `Hello World` → `olleH dlroW`
# - Input: `Learn Python Fast` → `nraeL nohtyP tsaF`

# %%
s = input("Enter Something : ")
l1 = s.split()
res = []
for i in l1:
    res.append(i[::-1])
res = " ".join(res)
print(res)
# res = " ".join([i[::-1] for i in s.split()])
# Out:
# Enter Something :  Python is Easy
# nohtyP si ysaE

# %% [markdown]
# ### 3) Case Pattern Identifier
# - `PYTHON` → Uppercase
# - `python` → Lowercase
# - `Python Programming` → Title Case

# %%
s = input("Enter Something : ")
if s.isupper():
    print("Uppercase")
elif s.islower():
    print("Lowercase")
elif s.istitle():
    print("Tital Case")
elif s.isdigit():
    print("Special Char")
else:
    print("Enter Valid Input")
# Out:
# Enter Something :  Python Programming
# Tital Case

# %% [markdown]
# ### 4) First and Last Occurrence Finder
# - `programming`, `g` → First:3 Last:10
# - `banana`, `a` → First:1 Last:5
# - `hello`, `z` → Not found

# %%
s = input("Enter  Something :")
find = input("Enter Find Char :")
print(f"First Occurance : {s.find(find)}")
print(f"Last Occurance : {s.rfind(find)}")
# Out:
# Enter  Something : programming
# Enter Find Char : g
# First Occurance : 3
# Last Occurance : 10

# %% [markdown]
# ### 5) Word Frequency Counter (ignore the case)
# - `Python is easy and Python is powerful` → python: 2
# - `Java is popular but java is verbose` → java: 2
# - `C is fast` → c:1

# %%
s1 = input("Enter Something :")
print(f"Count python: {s1.lower().count("python")}")
s2 = input("Enter Something :")
print(f"Count java: {s2.lower().count("java")}")
s3 = input("Enter Something :")
print(f"Count c: {s3.lower().count("c")}")
# Out:
# Enter Something : Python is easy and Python is powerful
# Count python: 2
# Enter Something : Java is popular but java is verbose
# Count java: 2
# Enter Something : C is fast
# Count c: 1

# %% [markdown]
# ### 6) Remove Extra Spaces
# - `  Python   is   fun  ` → `Python is fun`
# - `   Hello   World ` → `Hello World`
# - `NoExtraSpace` → `NoExtraSpace`

# %%
s = input("Enter Something :")
res = " ".join(s.split())
print(res)
# Out:
# Enter Something :  Python   is   fun
# Python is fun

# %% [markdown]
# ### 7) Prefix and Suffix Removal
# - `unhappy.txt` → `happy`
# - `pretest.py` → `test`
# - `unwanted.doc` → `wanted`

# %%
# s.removeprefix(prefix)
# s.removesuffix(suffix)
s = input("Enter Something: ")
res = s.removeprefix('un').removesuffix('.txt')
print(res)
# Out:
# Enter Something:  unhappy.txt
# happy

# %% [markdown]
# ### 8) Replace Vowels
# - `Programming` → `Pr*gr*mm*ng`
# - `Education` → `*d*c*t**n`
# - `Sky` → `Sky`

# %%
s1 = input("Enter Something: ")
vowels = 'aeiouAEIOU'
res = ""
for i in s1:
    if i in vowels:
        res += "*"
    else:
        res += i
print(res)

str2 = input("Enter Something (STR): ")

for v in "aeiouAEIOU":
    str2 = str2.replace(v, "*")

print(str2)
# Out:
# Enter Something:  Programming
# Pr*gr*mm*ng
# Enter Something (STR):  Education
# *d*c*t**n

# %% [markdown]
# ### 9) String Compression
# - `aaabbcccc` → `a3b2c4`
# - `xxxyyyz` → `x3y3z1`
# - `abcd` → `a1b1c1d1`

# %%
s = input("Enter Something: ")
res = ''
count = 1

for i in range(len(s)):
    if i + 1 < len(s) and s[i] == s[i + 1]:
        count += 1
    else:
        res += s[i] + str(count)
        count = 1

print(res)
# Out:
# Enter Something:  aaabbcccc
# a3b2c4

# %% [markdown]
# ### 10) Toggle Case (without using str.swapcase())
# - `PyThOn` → `pYtHoN`
# - `HELlo` → `helLO`
# - `Python` → `pYTHON`

# %%
s = input("Enter Something :")
res = ''
for i in s:
    if i.islower():
        res += i.upper()
    elif i.isupper():
        res += i.lower()
print(res)
# Out:
# Enter Something : Python
# pYTHON

# %% [markdown]
# ### 11) Username Validation
# #### valid username rules:
# 1. only alphabets and digits
# 2. does not start with a digit
# 3. length ≥ 6
#
# - `User123` → Valid
# - `123User` → Invalid
# - `Us@12` → Invalid

# %%
un = input("Enter Username: ")

if (
    un.isalnum() and          # only letters & digits
    not un[0].isdigit() and   # first character not digit
    len(un) >= 6              # minimum length
):
    print("Valid Username")
else:
    print("Invalid Username")
# Out:
# Enter Username:  User123
# Valid Username

# %% [markdown]
# ### 12) Palindrome Checker (ignore the case)
# - `Madam` → Palindrome
# - `Level` → Palindrome
# - `Python` → Not Palindrome

# %%
s = input("Enter Something: ")
s = s.lower()
if s == s[::-1]:
    print("Palindrom")
else:
    print("not palindrom")
# Out:
# Enter Something:  Madam
# Palindrom

# %% [markdown]
# ### 13) Longest Word Finder
# - `Python programming is interesting` → programming
# - `I love coding` → coding
# - `Data structures and algorithms` → structures

# %%
s = input("Enter Sentence: ")
words = s.split()
longest = words[0]
for w in words:
    if len(w) > len(longest):
        longest = w
print("Longest word:", longest)
# Out:
# Enter Sentence:  Python programming is interesting
# Longest word: programming

# %% [markdown]
# ### 14) Case Conversion
# - `python programming`
#   - Upper: PYTHON PROGRAMMING
#   - Lower: python programming
#   - Title: Python Programming
#   - Capitalize: Python programming

# %%
s = input("Enter Something: ")
print("Upper : ", s.upper())
print("Lower : ", s.lower())
print("Tital : ", s.title())
print("Capitalize : ", s.capitalize())
# Out:
# Enter Something:  python programming
# Upper :  PYTHON PROGRAMMING
# Lower :  python programming
# Tital :  Python Programming
# Capitalize :  Python programming

# %% [markdown]
# ### 15) Custom Split
# - `apple,banana,grape`
# - `10|20|30`
# - `A-B-C-D`

# %%
# s = input("Enter Something: ")
# l1 = s.split("|")
# print(l1)

s = input("Enter String: ")
sep = input("Enter Separator: ")
res = []
temp = ""
for ch in s:
    if ch == sep:
        res.append(temp)
        temp = ""
    else:
        temp += ch
res.append(temp)   # add last part
print(res)
# Out:
# Enter String:  apple, banana, grape
# Enter Separator:  ,
# ['apple', ' banana', ' grape']
